# %% [markdown]
# #Análise de vendas
# Esse notebook realiza uma análise exploratória de dados de vendas. Verificar produtos com maior lucro e comissão de vendas e obter insights úteis para o negócio.

# %% [markdown]
# #Importação e Visualização inicial dos Dados

# %%
import pandas as pd

vendas_df = pd.read_excel('/content/drive/MyDrive/Vendas - Dez.xlsx')

# %%
display(vendas_df)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# 0              5             114          570
# 1              1             269          269
# 2              2             363          726
# 3              1             250          250
# 4              3              92          276
# ...          ...             ...          ...
# 7084           2             102          204
# 7085           4             270         1080
# 7086           1              87           87
# 7087           1             108          108
# 7088           2             133          266
#
# [7089 rows x 7 columns]

# %% [markdown]
# #Mostrando os 5 produtos que mais foram vendidos

# %%
mais_5vendidos = vendas_df.groupby('Produto')['Quantidade'].sum()
mais_5vendidos = mais_5vendidos.sort_values(ascending=False).head()
display(mais_5vendidos)
# Out:
# Produto
# Camisa Estampa        173
# Polo Linho            163
# Camiseta Xadrez       159
# Camisa Gola V Liso    158
# Pulseira Listrado     157
# Name: Quantidade, dtype: int64

# %% [markdown]
# #Mostrando o valor obtido na venda de cada produto

# %%
total_vendas=vendas_df[['Produto', 'Valor Final']].groupby('Produto').sum()
display(total_vendas)
# Out:
#                   Valor Final
# Produto
# Bermuda                 18450
# Bermuda Estampa         18590
# Bermuda Linho           25545
# Bermuda Liso            18683
# Bermuda Listrado        20212
# ...                       ...
# Tênis Estampa           32000
# Tênis Linho             34986
# Tênis Liso              34048
# Tênis Listrado          25938
# Tênis Xadrez            29526
#
# [120 rows x 1 columns]

# %% [markdown]
# #Adicionando uma nova coluna com o nome "Comissão"

# %%
vendas_df['Comissão']=vendas_df['Valor Final']*0.05
display(vendas_df)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final  Comissão
# 0              5             114          570     28.50
# 1              1             269          269     13.45
# 2              2             363          726     36.30
# 3              1             250          250     12.50
# 4              3              92          276     13.80
# ...          ...             ...          ...       ...
# 7084           2             102          204     10.20
# 7085           4             270         1080     54.00
# 7086           1              87           87      4.35
# 7087           1             108          108      5.40
# 7088           2             133          266     13.30
#
# [7089 rows x 8 columns]

# %% [markdown]
# #A média de valor obtido em cada produto

# %%
media_produtos=vendas_df[['Produto', 'Valor Final']].groupby('Produto').mean()
display(media_produtos)
# Out:
#                   Valor Final
# Produto
# Bermuda            312.711864
# Bermuda Estampa    379.387755
# Bermuda Linho      418.770492
# Bermuda Liso       424.613636
# Bermuda Listrado   367.490909
# ...                       ...
# Tênis Estampa      571.428571
# Tênis Linho        603.206897
# Tênis Liso         567.466667
# Tênis Listrado     529.346939
# Tênis Xadrez       546.777778
#
# [120 rows x 1 columns]

# %% [markdown]
# #Filtrando as vendas para aparecer apenas as que tiveram comissão maior que 30

# %%
comissao_maior_que_trinta=vendas_df.loc[vendas_df['Comissão']>30,['Produto', 'Valor Final', 'Comissão']]
display(comissao_maior_que_trinta)
# Out:
#               Produto  Valor Final  Comissão
# 2     Sapato Listrado          726     36.30
# 11    Camiseta Xadrez         1000     50.00
# 14       Calça Xadrez          925     46.25
# 18             Sapato         1750     87.50
# 27       Sapato Linho         1955     97.75
# ...               ...          ...       ...
# 7077  Bermuda Estampa          676     33.80
# 7078          Mochila         1080     54.00
# 7082   Cinto Listrado          642     32.10
# 7083          Mochila         1080     54.00
# 7085          Mochila         1080     54.00
#
# [1403 rows x 3 columns]

# %% [markdown]
# #Mostrando quais produtos tiveram a maior comissão

# %%
maior_comissao = vendas_df[['Produto', 'Comissão' ]].groupby('Produto').sum()
maior_comissao = maior_comissao.sort_values(by='Comissão', ascending=False)
display(maior_comissao)
# Out:
#                 Comissão
# Produto
# Terno Linho      5137.50
# Terno Estampa    5083.20
# Terno Listrado   4643.95
# Terno            4130.00
# Terno Liso       3996.00
# ...                  ...
# Pulseira          301.00
# Meia Liso         292.60
# Meia Xadrez       223.45
# Meia Listrado     190.55
# Meia              168.00
#
# [120 rows x 1 columns]

# %% [markdown]
# #Adicionando o mês em que as vendas foram feitas

# %%
vendas_df["Mês"] = "Dezembro"
display(vendas_df)
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final  Comissão       Mês
# 0              5             114          570     28.50  Dezembro
# 1              1             269          269     13.45  Dezembro
# 2              2             363          726     36.30  Dezembro
# 3              1             250          250     12.50  Dezembro
# 4              3              92          276     13.80  Dezembro
# ...          ...             ...          ...       ...       ...
# 7084           2             102          204     10.20  Dezembro
# 7085           4             270         1080     54.00  Dezembro
# 7086           1              87           87      4.35  Dezembro
# 7087           1             108          108      5.40  Dezembro
# 7088           2             133          266     13.30  Dezembro
#
# [7089 rows x 9 columns]

# %% [markdown]
# #Mostrando o valor total das vendas feitas em cada dia

# %%
vendas_por_dia = vendas_df[["Data", "Valor Final"]].groupby('Data').sum()
display(vendas_por_dia)
# Out:
#             Valor Final
# Data
# 2019-12-01       123143
# 2019-12-02       123624
# 2019-12-03       111037
# 2019-12-04       123066
# 2019-12-05       111079
# 2019-12-06        95560
# 2019-12-07       110039
# 2019-12-08       110096
# 2019-12-09       115396
# 2019-12-10       125716
# 2019-12-11       104931
# 2019-12-12       122864
# 2019-12-13       111569
# 2019-12-14       112654
# 2019-12-15       124733
# 2019-12-16       122648
# 2019-12-17       111868
# 2019-12-18       115091
# 2019-12-19       108191
# 2019-12-20       123214
# 2019-12-21       123973
# 2019-12-22       110931
# 2019-12-23       129418
# 2019-12-24       110618
# 2019-12-25       114261
# 2019-12-26        21591

# %% [markdown]
# #Colocando a ordem do DataFrame de acordo com o maior valor de vendas até o menor valor de vendas.

# %%
vendas_df = vendas_df.sort_values(by="Valor Final", ascending=False)
display(vendas_df)
# Out:
#       Código Venda       Data                           ID Loja      Produto  \
# 4864         68475 2019-12-18        Shopping Center Interlagos  Terno Linho
# 6888         69861 2019-12-25         Passei das Águas Shopping  Terno Linho
# 50           65049 2019-12-01                Iguatemi Esplanada  Terno Linho
# 3136         67180 2019-12-12                  Shopping Morumbi  Terno Linho
# 6235         69389 2019-12-23                 Iguatemi Campinas  Terno Linho
# ...            ...        ...                               ...          ...
# 5840         69139 2019-12-21               Bourbon Shopping SP         Meia
# 6663         69678 2019-12-24                   Shopping Recife         Meia
# 6555         69597 2019-12-24                    Norte Shopping         Meia
# 1424         65986 2019-12-06                 Iguatemi Campinas         Meia
# 6974         69922 2019-12-25  Shopping Center Leste Aricanduva         Meia
#
#       Quantidade  Valor Unitário  Valor Final  Comissão       Mês
# 4864           5             750         3750     187.5  Dezembro
# 6888           5             750         3750     187.5  Dezembro
# 50             5             750         3750     187.5  Dezembro
# 3136           5             750         3750     187.5  Dezembro
# 6235           5             750         3750     187.5  Dezembro
# ...          ...             ...          ...       ...       ...
# 5840           1              30           30       1.5  Dezembro
# 6663           1              30           30       1.5  Dezembro
# 6555           1              30           30       1.5  Dezembro
# 1424           1              30           30       1.5  Dezembro
# 6974           1              30           30       1.5  Dezembro
#
# [7089 rows x 9 columns]

# %% [markdown]
# #Conclusão
# A análise realizada permitiu entender melhor os dados de vendas, identificar vendas relevantes, valor recebido em cada dia, maior valor recebido. Recomenda-se aprofundar com gráficos ou análise por período para gerar insights ainda mais estratégicos.
